# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('/content/drive/My Drive/496 project/raw_sales.csv')

# Convert 'datesold' column to datetime data type
df['datesold'] = pd.to_datetime(df['datesold'])


# Encode non-numeric data (here we use one-hot encoding)
df_encoded = pd.get_dummies(df, columns=['propertyType'])

# data standardization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_encoded[['price', 'bedrooms']] = scaler.fit_transform(df_encoded[['price', 'bedrooms']])

# Sequence data processing (here we sort the data by date and reset the index)
df_encoded.sort_values(by='datesold', inplace=True)
df_encoded.reset_index(drop=True, inplace=True)

print(df_encoded)
# Out:
#         datesold  postcode     price  bedrooms  propertyType_house  \
# 0     2007-02-07      2607 -0.300800  0.788251                   1
# 1     2007-02-27      2906 -1.135011 -0.262987                   1
# 2     2007-03-07      2905 -1.000118 -0.262987                   1
# 3     2007-03-09      2905 -0.815526  0.788251                   1
# 4     2007-03-21      2906 -1.064015 -0.262987                   1
# ...          ...       ...       ...       ...                 ...
# 29575 2019-07-26      2902  0.169553  0.788251                   1
# 29576 2019-07-26      2601 -0.073610 -1.314226                   0
# 29577 2019-07-27      2905  0.000936  0.788251                   1
# 29578 2019-07-27      2615  0.134055  0.788251                   1
# 29579 2019-07-27      2905  0.906144  1.839490                   1
#
#        propertyType_unit
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 29575                  0
# 29576                  1
# 29577                  0
# 29578                  0
# 29579                  0
#
# [29580 rows x 6 columns]

# %%
df_encoded.head()
# Out:
#     datesold  postcode     price  bedrooms  propertyType_house  \
# 0 2007-02-07      2607 -0.300800  0.788251                   1
# 1 2007-02-27      2906 -1.135011 -0.262987                   1
# 2 2007-03-07      2905 -1.000118 -0.262987                   1
# 3 2007-03-09      2905 -0.815526  0.788251                   1
# 4 2007-03-21      2906 -1.064015 -0.262987                   1
#
#    propertyType_unit
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
# Define a function to remove outliers from grouped data
def remove_outliers(group):
    Q1 = group['price'].quantile(0.25)
    Q3 = group['price'].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return group[(group['price'] >= lower_bound) & (group['price'] <= upper_bound)]

# Add a 'year' column to the data, indicating the year of each data
df['year'] = df['datesold'].dt.year

# Use the groupby function to group by the 'year' and 'postcode' columns and apply the remove_outliers function
df = df.groupby(['year', 'postcode']).apply(remove_outliers).reset_index(drop=True)

# Remove the 'year' column as we don't need it anymore
df.drop('year', axis=1, inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler
# First, one-hot encode the non-numeric features
df = pd.get_dummies(df, columns=['propertyType'])

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df[['price', 'bedrooms', 'propertyType_house', 'propertyType_unit']])

# Convert normalized data back to DataFrame
scaled_df = pd.DataFrame(scaled_data, columns=['price', 'bedrooms', 'propertyType_house', 'propertyType_unit'])
scaled_df['datesold'] = df['datesold']
scaled_df['postcode'] = df['postcode']
# group by region
grouped_data = scaled_df.groupby('postcode')

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense


# Define a function for converting time series data into supervised learning data
def to_supervised(data, n_in=1, n_out=1):
    n_vars = data.shape[1]
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(data.shift(i))
        names += [('var%d(t-%d)' % (j + 1, i)) for j in range(n_vars)]
    for i in range(0, n_out):
        cols.append(data.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j + 1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j + 1, i)) for j in range(n_vars)]
    supervised_data = pd.concat(cols, axis=1)
    supervised_data.columns = names
    supervised_data.dropna(inplace=True)
    return supervised_data


def train_rnn_model(train_data, n_input, n_features):
    # Separate input features and target variables
    X_train, y_train = train_data[:, :n_features*3], train_data[:, -4]

    # Reshape the input data to meet the input requirements of the RNN
    X_train = X_train.reshape((X_train.shape[0], n_input, n_features))

    # Build the RNN model
    model = Sequential()
    model.add(SimpleRNN(50, activation='relu', input_shape=(n_input, n_features)))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    # training model
    model.fit(X_train, y_train, epochs=200, verbose=0)

    return model

# %%
def predict_next_period(model, last_n_periods_data, n_input, n_features):
    # Reshape the input data to meet the input requirements of the RNN
    X_test = last_n_periods_data.reshape((1, n_input, n_features))
    
    # Use the trained model to make predictions
    y_pred = model.predict(X_test)
    
    return y_pred[0, 0]

# %%
def plot_true_vs_predicted(y_true, y_pred, title="True vs. Predicted"):
    plt.plot(y_true, label="True")
    plt.plot(y_pred, label="Predicted")

# %%
from sklearn.metrics import mean_squared_error

n_input = 3
n_features = 5
postcode_rmse_train = {}
postcode_rmse_val = {}
i = 1
plt.figure(figsize = (3,27))

for postcode, group in grouped_data:
    group.sort_values(by='datesold', inplace=True)
    group.reset_index(drop=True, inplace=True)

    data = group.drop(columns=['datesold','postcode']).values.astype('float32')

    # Transform data into supervised learning data
    supervised_data = to_supervised(pd.DataFrame(data), n_in=n_input)
    train_data = supervised_data.values
    # Divide the data into training and validation sets
    train_size = int(len(train_data) * 0.7)
    train_data_train = train_data[:train_size]
    train_data_val = train_data[train_size:]

    
    # Extract the input and output of the training set and validation set
    X_train = train_data_train[:, :n_features*3].reshape((-1, n_input, n_features))
    y_train = train_data_train[:, -4]
    X_val = train_data_val[:, :n_features*3].reshape((-1, n_input, n_features))
    y_val = train_data_val[:, -4]
    # Create and train an RNN model
    rnn_model = train_rnn_model(train_data_train, n_input, n_features)

    # Prepare test data (here we use the data from the last n_input period as input)
    last_n_periods_data = train_data[-1, -n_features * n_input:]

    # Predict the price of the next period
    next_period_price = predict_next_period(rnn_model, last_n_periods_data, n_input, n_features)
    print(f"Predicted price for next period in postcode {postcode}: {next_period_price}")

    # Calculate the evaluation metrics for the predicted results
    y_train_pred = rnn_model.predict(X_train)
    y_val_pred = rnn_model.predict(X_val)

    rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
    rmse_val = np.sqrt(mean_squared_error(y_val,y_val_pred))

    # Draw a comparison chart
    plt.subplot(27,1,i)
    plot_true_vs_predicted(np.concatenate((y_train,y_val)), np.concatenate((y_train_pred,y_val_pred)), title=f"True vs. Predicted for postcode {postcode}")
    i += 1
    

    # save the RMSE result into a dictionary
    postcode_rmse_train[postcode] = rmse_train
    postcode_rmse_val[postcode] = rmse_val
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 245ms/step
# Predicted price for next period in postcode 2600: 0.3770342171192169
# 14/14 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 150ms/step
# Predicted price for next period in postcode 2601: 0.44742947816848755
# 6/6 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 166ms/step
# Predicted price for next period in postcode 2602: 0.703582763671875
# 55/55 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 157ms/step
# Predicted price for next period in postcode 2603: 0.18290656805038452
# 18/18 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 220ms/step
# Predicted price for next period in postcode 2604: 0.3254956007003784
# 23/23 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 233ms/step
# Predicted price for next period in postcode 2605: 0.4426164925098419
# 16/16 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 1s 1s/step
# Predicted price for next period in postcode 2606: 0.08269909769296646
# 14/14 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 213ms/step
# Predicted price for next period in postcode 2607: 0.4655672609806061
# 20/20 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 254ms/step
# Predicted price for next period in postcode 2609: 0.05292079970240593
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 165ms/step
# Predicted price for next period in postcode 2611: 0.44986993074417114
# 39/39 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 154ms/step
# Predicted price for next period in postcode 2612: 0.37306249141693115
# 26/26 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 167ms/step
# Predicted price for next period in postcode 2614: 0.46407270431518555
# 23/23 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 149ms/step
# Predicted price for next period in postcode 2615: 0.5105001330375671
# 77/77 [==============================] - 0s 2ms/step
# 33/33 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 145ms/step
# Predicted price for next period in postcode 2616: -0.04614098370075226
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 153ms/step
# Predicted price for next period in postcode 2617: 0.4186190664768219
# 46/46 [==============================] - 0s 2ms/step
# 20/20 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 143ms/step
# Predicted price for next period in postcode 2618: 0.22759602963924408
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 142ms/step
# Predicted price for next period in postcode 2620: 0.11006321012973785
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 308ms/step
# Predicted price for next period in postcode 2900: 0.19069696962833405
# 3/3 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 277ms/step
# Predicted price for next period in postcode 2902: 0.3740521967411041
# 21/21 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 163ms/step
# Predicted price for next period in postcode 2903: 0.5837847590446472
# 15/15 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 158ms/step
# Predicted price for next period in postcode 2904: 0.5565438270568848
# 20/20 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 168ms/step
# Predicted price for next period in postcode 2905: 0.7250568270683289
# 48/48 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 148ms/step
# Predicted price for next period in postcode 2906: 0.10458576679229736
# 36/36 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 147ms/step
# Predicted price for next period in postcode 2911: 0.4066506028175354
# 6/6 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 148ms/step
# Predicted price for next period in postcode 2912: 0.3858959972858429
# 11/11 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 223ms/step
# Predicted price for next period in postcode 2913: 0.4979555010795593
# 55/55 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 142ms/step
# Predicted price for next period in postcode 2914: 0.6019240617752075
# 42/42 [==============================] - 0s 2ms/step
# 18/18 [==============================] - 0s 2ms/step

# %%
# convert dictionary to list
postcodes = list(postcode_rmse_train.keys())
rmse_values_train = list(postcode_rmse_train.values())
rmse_values_val = list(postcode_rmse_val.values())
postcodes = [str(a) for a in postcodes]
# draw histogram
plt.figure(figsize=(10, 5))
plt.bar(postcodes, rmse_values_val, label = 'validation set')
plt.bar(postcodes, rmse_values_train, label = 'train set')
plt.xlabel("Postcode")
plt.tick_params(axis='x', labelsize=6)    
plt.ylabel("RMSE")
plt.title("RMSE for different postcodes")
plt.legend()
plt.show()

# %%
from keras.callbacks import EarlyStopping
def train_rnn_model(train_data, n_input, n_features, validation_data=None):
    # Separate input features and target variables
    X_train, y_train = train_data[:, :n_features*3], train_data[:, -4]

    # Reshape the input data to meet the input requirements of the RNN
    X_train = X_train.reshape((X_train.shape[0], n_input, n_features))

    # Build the RNN model
    model = Sequential()
    model.add(SimpleRNN(50, activation='relu', input_shape=(n_input, n_features)))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    # Add EarlyStopping callback
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    callbacks = [early_stopping] if validation_data is not None else None

    # Add validation data and callbacks in the fit function
    model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=0, validation_data=validation_data, callbacks=callbacks)

    return model

# %%
from sklearn.metrics import mean_squared_error

n_input = 3
n_features = 5
postcode_rmse_train_es = {}
postcode_rmse_val_es = {}
i = 1
plt.figure(figsize = (3,27))

for postcode, group in grouped_data:
    group.sort_values(by='datesold', inplace=True)
    group.reset_index(drop=True, inplace=True)

    data = group.drop(columns=['datesold','postcode']).values.astype('float32')

    # Transform data into supervised learning data
    supervised_data = to_supervised(pd.DataFrame(data), n_in=n_input)
    train_data = supervised_data.values
    # Divide the data into training and validation sets
    train_size = int(len(train_data) * 0.7)
    train_data_train = train_data[:train_size]
    train_data_val = train_data[train_size:]

    
    # Extract the input and output of the training set and validation set
    X_train = train_data_train[:, :n_features*3].reshape((-1, n_input, n_features))
    y_train = train_data_train[:, -4]
    X_val = train_data_val[:, :n_features*3].reshape((-1, n_input, n_features))
    y_val = train_data_val[:, -4]
    # Create and train an RNN model
    rnn_model = train_rnn_model(train_data_train, n_input, n_features)

    # Prepare test data (here we use the data from the last n_input period as input)
    last_n_periods_data = train_data[-1, -n_features * n_input:]

    # Predict the price of the next period
    next_period_price = predict_next_period(rnn_model, last_n_periods_data, n_input, n_features)
    print(f"Predicted price for next period in postcode {postcode}: {next_period_price}")

    # Calculate the evaluation metric of the forecast
    y_train_pred = rnn_model.predict(X_train)
    y_val_pred = rnn_model.predict(X_val)

    rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
    rmse_val = np.sqrt(mean_squared_error(y_val,y_val_pred))

    # Draw a comparison chart
    plt.subplot(27,1,i)
    plot_true_vs_predicted(np.concatenate((y_train,y_val)), np.concatenate((y_train_pred,y_val_pred)), title=f"True vs. Predicted for postcode {postcode}")
    i += 1
    
    # save the RMSE result into a dictionary
    postcode_rmse_train_es[postcode] = rmse_train
    postcode_rmse_val_es[postcode] = rmse_val

plt.show()
# Out:
# 1/1 [==============================] - 0s 160ms/step
# Predicted price for next period in postcode 2600: 0.49019843339920044
# 14/14 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 158ms/step
# Predicted price for next period in postcode 2601: 0.24786125123500824
# 6/6 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 140ms/step
# Predicted price for next period in postcode 2602: 0.6926829218864441
# 55/55 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 235ms/step
# Predicted price for next period in postcode 2603: 0.18602579832077026
# 18/18 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 170ms/step
# Predicted price for next period in postcode 2604: 0.2225112020969391
# 23/23 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 161ms/step
# Predicted price for next period in postcode 2605: 0.3760499954223633
# 16/16 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 157ms/step
# Predicted price for next period in postcode 2606: 0.06738612800836563
# 14/14 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 152ms/step
# Predicted price for next period in postcode 2607: 0.4268001914024353
# 20/20 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 209ms/step
# Predicted price for next period in postcode 2609: 0.09780353307723999
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 145ms/step
# Predicted price for next period in postcode 2611: 0.7347294688224792
# 39/39 [==============================] - 0s 2ms/step
# 17/17 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 159ms/step
# Predicted price for next period in postcode 2612: 0.47892701625823975
# 26/26 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 142ms/step
# Predicted price for next period in postcode 2614: 0.5945824980735779
# 23/23 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 238ms/step
# Predicted price for next period in postcode 2615: 0.5154105424880981
# 77/77 [==============================] - 0s 2ms/step
# 33/33 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 1s 1s/step
# Predicted price for next period in postcode 2616: 0.3421268165111542
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 272ms/step
# Predicted price for next period in postcode 2617: 0.24487736821174622
# 46/46 [==============================] - 0s 3ms/step
# 20/20 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 187ms/step
# Predicted price for next period in postcode 2618: -0.06393488496541977
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 161ms/step
# Predicted price for next period in postcode 2620: 0.3065168559551239
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 153ms/step
# Predicted price for next period in postcode 2900: 0.06999581307172775
# 3/3 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 150ms/step
# Predicted price for next period in postcode 2902: 0.4326059818267822
# 21/21 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 211ms/step
# Predicted price for next period in postcode 2903: 0.30881768465042114
# 15/15 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 155ms/step
# Predicted price for next period in postcode 2904: 0.32376036047935486
# 20/20 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 217ms/step
# Predicted price for next period in postcode 2905: 0.6613607406616211
# 48/48 [==============================] - 0s 3ms/step
# 21/21 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 146ms/step
# Predicted price for next period in postcode 2906: 0.6058006882667542
# 36/36 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 224ms/step
# Predicted price for next period in postcode 2911: 0.29335901141166687
# 6/6 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 207ms/step
# Predicted price for next period in postcode 2912: 0.333609402179718
# 11/11 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 180ms/step
# Predicted price for next period in postcode 2913: 0.6733605265617371
# 55/55 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 229ms/step
# Predicted price for next period in postcode 2914: 0.46018484234809875
# 42/42 [==============================] - 0s 2ms/step
# 18/18 [==============================] - 0s 2ms/step

# %%
# convert dictionary to list
postcodes = list(postcode_rmse_train_es.keys())
rmse_values_train = list(postcode_rmse_train.values())
rmse_values_val = list(postcode_rmse_val.values())
rmse_values_train_es = list(postcode_rmse_train_es.values())
rmse_values_val_es = list(postcode_rmse_val_es.values())
postcodes = [str(a) for a in postcodes]
# draw histogram
plt.figure(figsize=(10, 5))
plt.bar(postcodes, rmse_values_val, label = 'validation set in normal model')
plt.bar(postcodes, rmse_values_val_es, label = 'validation set in early stop model')
plt.bar(postcodes, rmse_values_train_es, label = 'train set in early stop model')
plt.bar(postcodes, rmse_values_train, label = 'train set in normal model')

plt.xlabel("Postcode")
plt.tick_params(axis='x', labelsize=6)    
plt.ylabel("RMSE")
plt.title("RMSE for different postcodes")
plt.legend()
plt.show()
